# %% [markdown]
# # 00 Study Area Setup
#
# FloodSense Lokoja is a Python-based flood risk intelligence and decision-support system for Lokoja, Kogi State, Nigeria.
#
# This notebook introduces the study area, project objectives, configuration, and project paths.

# %% [markdown]
# ## Objectives
#
# - Define Lokoja as the single study area.
# - Load the project configuration.
# - Inspect expected project directories.
# - Confirm the target projected CRS.

# %%
from floodsense.config import load_config
from floodsense.paths import ensure_project_directories, get_project_root

config = load_config()
ensure_project_directories(config)

print('Project root:', get_project_root())
print('Study area:', config['project']['study_area'])
print('Target CRS:', config['project']['crs'])

# %% [markdown]
# ## TODO
#
# Place the Lokoja boundary file in `data/raw/boundary/` before running preprocessing.
